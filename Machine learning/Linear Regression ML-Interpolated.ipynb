# %%
# !pip install yfinance as yf
# Out:
# Requirement already satisfied: yfinance in /Users/chelseaconrad/opt/anaconda3/lib/python3.8/site-packages (0.1.55)
# Requirement already satisfied: as in /Users/chelseaconrad/opt/anaconda3/lib/python3.8/site-packages (0.1)
# Requirement already satisfied: yf in /Users/chelseaconrad/opt/anaconda3/lib/python3.8/site-packages (0.0.2)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/chelseaconrad/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: requests>=2.20 in /Users/chelseaconrad/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (2.25.1)
# Requirement already satisfied: lxml>=4.5.1 in /Users/chelseaconrad/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (4.6.2)
# Requirement already satisfied: pandas>=0.24 in /Users/chelseaconrad/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.2.1)
# Requirement already satisfied: numpy>=1.15 in /Users/chelseaconrad/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/chelseaconrad/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/chelseaconrad/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2020.5)
# Requirement already satisfied: six>=1.5 in /Users/chelseaconrad/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/chelseaconrad/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/chelseaconrad/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (1.26.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chelseaconrad/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/chelseaconrad/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (4.0.0)

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from datetime import datetime as dt
from sklearn.model_selection import train_test_split
import numpy as np
import yfinance as yf

# %%
combo_multi_path = "/Users/chelseaconrad/Desktop/Final_Project_WSB/Data/combo_count_multiindex.csv"
ticker_path = "/Users/chelseaconrad/Desktop/Final_Project_WSB/Data/final_ticker_list.csv"

# %%
count_df = pd.read_csv(combo_multi_path, header=[0,1], index_col=0)
ticker_list = pd.read_csv(ticker_path)

# %%
ticker_list = ticker_list["Tickers"].to_list()

# %%
count_df.head()
# Out:
#                 AMC     PUBM     GOGO     ISUN     CLVS      GME      SKT  \
#            mentions mentions mentions mentions mentions mentions mentions
# date
# 2020-12-08     11.0      2.0      6.0      0.0      0.0   1841.0      0.0
# 2020-12-09      2.0     31.0      6.0      0.0      0.0   1938.0      0.0
# 2020-12-10     26.0      3.0      1.0      0.0      0.0    591.0      1.0
# 2020-12-11     15.0      3.0      0.0      0.0      0.0    428.0      2.0
# 2020-12-12     34.0      0.0      1.0      0.0      0.0    269.0      0.0
#
#                LGND     TRIT     ESPR  ...       JP     AAPL       ET  \
#            mentions mentions mentions  ... mentions mentions mentions
# date                                   ...
# 2020-12-08      0.0      0.0      0.0  ...      4.0     88.0    136.0
# 2020-12-09      0.0      0.0      1.0  ...     69.0    213.0    281.0
# 2020-12-10      0.0      2.0      0.0  ...     63.0    114.0    242.0
# 2020-12-11      2.0      0.0      0.0  ...     23.0    114.0    249.0
# 2020-12-12      0.0      0.0      0.0  ...     18.0     71.0    165.0
#
#                 MSM       FB     TLRY      BRO     CRSR     IBKR      BIO
#            mentions mentions mentions mentions mentions mentions mentions
# date
# 2020-12-08      0.0     11.0      1.0     84.0     46.0      5.0      2.0
# 2020-12-09      0.0    168.0      3.0    164.0     91.0     11.0      8.0
# 2020-12-10      4.0    159.0      1.0    135.0     52.0      8.0     13.0
# 2020-12-11      9.0     54.0      0.0    194.0    103.0     18.0     13.0
# 2020-12-12      0.0     35.0      0.0    144.0     42.0     15.0     11.0
#
# [5 rows x 82 columns]

# %%
df = pd.DataFrame(yf.download(ticker_list, start="2020-12-08", end="2021-02-05", interval="1d", group_by='tickers', index=False))
# Out:
# [*********************100%***********************]  82 of 82 completed

# %%
amc_count = pd.DataFrame(count_df["AMC"])

# %%
amc_price = df["AMC"]

# %%
# enter combined AMC df info
amc_result = amc_count.join(amc_price)
amc_result
# Out:
#             mentions   Open       High    Low  Close  Adj Close        Volume
# date
# 2020-12-08      11.0   3.61   4.020000   3.61   3.98       3.98  2.953060e+07
# 2020-12-09       2.0   4.22   4.330000   3.75   3.86       3.86  2.099120e+07
# 2020-12-10      26.0   3.79   4.100000   3.77   4.09       4.09  1.987280e+07
# 2020-12-11      15.0   4.04   4.250000   3.87   3.92       3.92  2.231040e+07
# 2020-12-12      34.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2020-12-13      12.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2020-12-14      47.0   4.01   4.010000   3.00   3.19       3.19  6.715900e+07
# 2020-12-15      67.0   3.24   3.240000   2.76   2.86       2.86  5.443210e+07
# 2020-12-16      67.0   2.87   2.890000   2.72   2.78       2.78  2.542320e+07
# 2020-12-17      45.0   2.80   2.950000   2.74   2.85       2.85  2.379930e+07
# 2020-12-18      16.0   2.85   2.850000   2.76   2.80       2.80  2.194170e+07
# 2020-12-19      15.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2020-12-20       8.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2020-12-21      66.0   2.61   2.740000   2.58   2.68       2.68  2.269980e+07
# 2020-12-22      31.0   2.73   2.750000   2.52   2.59       2.59  2.163840e+07
# 2020-12-23      27.0   2.58   2.650000   2.54   2.56       2.56  1.572480e+07
# 2020-12-24       7.0   2.59   2.600000   2.48   2.51       2.51  1.109420e+07
# 2020-12-25      18.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2020-12-26      15.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2020-12-27      13.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2020-12-28      40.0   2.63   2.630000   2.36   2.39       2.39  2.394270e+07
# 2020-12-29      41.0   2.44   2.460000   2.28   2.29       2.29  2.108610e+07
# 2020-12-30      40.0   2.30   2.300000   2.13   2.16       2.16  4.027840e+07
# 2020-12-31      32.0   2.17   2.220000   2.08   2.12       2.12  2.823430e+07
# 2021-01-01       5.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2021-01-02       2.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2021-01-03       3.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2021-01-04       5.0   2.20   2.200000   2.00   2.01       2.01  2.987380e+07
# 2021-01-05       8.0   1.99   2.030000   1.91   1.98       1.98  2.814830e+07
# 2021-01-06       9.0   2.03   2.230000   1.97   2.01       2.01  6.736330e+07
# 2021-01-07      10.0   2.08   2.110000   2.02   2.05       2.05  2.615050e+07
# 2021-01-08       4.0   2.09   2.210000   2.07   2.14       2.14  3.955330e+07
# 2021-01-09       2.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2021-01-10       1.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2021-01-11       8.0   2.16   2.270000   2.15   2.20       2.20  4.169580e+07
# 2021-01-12       8.0   2.24   2.390000   2.24   2.29       2.29  4.178430e+07
# 2021-01-13       9.0   2.33   2.380000   2.13   2.18       2.18  4.584770e+07
# 2021-01-14      18.0   2.22   2.320000   2.13   2.18       2.18  4.963880e+07
# 2021-01-15     104.0   2.20   2.550000   2.18   2.33       2.33  1.623564e+08
# 2021-01-16      21.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2021-01-17      26.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2021-01-18      66.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2021-01-19     160.0   2.80   3.200000   2.57   3.06       3.06  2.562760e+08
# 2021-01-20      89.0   3.29   3.340000   2.75   2.97       2.97  1.818622e+08
# 2021-01-21      44.0   3.00   3.060000   2.85   2.98       2.98  6.482380e+07
# 2021-01-22     611.0   2.91   3.740000   2.81   3.51       3.51  2.682734e+08
# 2021-01-23     103.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2021-01-24      42.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2021-01-25     634.0   4.71   4.880000   3.85   4.42       4.42  4.432381e+08
# 2021-01-26     231.0   5.09   5.190000   4.37   4.96       4.96  4.568502e+08
# 2021-01-27   20976.0  20.34  20.360001  11.01  19.90      19.90  1.222342e+09
# 2021-01-28   32927.0  11.98  16.500000   6.51   8.63       8.63  5.912239e+08
# 2021-01-29   24385.0  14.31  16.000000  11.60  13.26      13.26  6.021933e+08
# 2021-01-30   17968.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2021-01-31   13640.0    NaN        NaN    NaN    NaN        NaN           NaN
# 2021-02-01   24050.0  17.00  17.250000  12.91  13.30      13.30  4.346080e+08
# 2021-02-02   19798.0   9.48  10.100000   6.00   7.82       7.82  4.627759e+08
# 2021-02-03    3630.0   8.85   9.770000   7.89   8.97       8.97  2.214051e+08
# 2021-02-04      95.0   8.70   8.740000   7.00   7.09       7.09  1.629858e+08

# %%
amc_result['datetime']=amc_result.index.to_pydatetime()
amc_result["Year"]=amc_result['datetime'].dt.year
amc_result["Month"]=amc_result['datetime'].dt.month
amc_result["Day"]=amc_result['datetime'].dt.day
# amc_result['date2']=amc_result.index
amc_result.head()
# Out:
#             mentions  Open  High   Low  Close  Adj Close      Volume  \
# date
# 2020-12-08      11.0  3.61  4.02  3.61   3.98       3.98  29530600.0
# 2020-12-09       2.0  4.22  4.33  3.75   3.86       3.86  20991200.0
# 2020-12-10      26.0  3.79  4.10  3.77   4.09       4.09  19872800.0
# 2020-12-11      15.0  4.04  4.25  3.87   3.92       3.92  22310400.0
# 2020-12-12      34.0   NaN   NaN   NaN    NaN        NaN         NaN
#
#              datetime  Year  Month  Day
# date
# 2020-12-08 2020-12-08  2020     12    8
# 2020-12-09 2020-12-09  2020     12    9
# 2020-12-10 2020-12-10  2020     12   10
# 2020-12-11 2020-12-11  2020     12   11
# 2020-12-12 2020-12-12  2020     12   12

# %%
#interpolated the NaN columns
df_interpol = amc_result.resample('D')\
                .mean()
df_interpol['Close'] = df_interpol['Close'].interpolate()
df_interpol['Open'] = df_interpol['Open'].interpolate()
df_interpol['High'] = df_interpol['High'].interpolate()
df_interpol['Low'] = df_interpol['Low'].interpolate()
df_interpol['Adj Close'] = df_interpol['Adj Close'].interpolate()
df_interpol['datetime']=df_interpol.index.to_pydatetime()
# df_interpol['Volume'] = df_interpol['Volume'].interpolate()
df_interpol.head(10)
# Out:
#             mentions  Open  High   Low     Close  Adj Close      Volume  Year  \
# date
# 2020-12-08      11.0  3.61  4.02  3.61  3.980000   3.980000  29530600.0  2020
# 2020-12-09       2.0  4.22  4.33  3.75  3.860000   3.860000  20991200.0  2020
# 2020-12-10      26.0  3.79  4.10  3.77  4.090000   4.090000  19872800.0  2020
# 2020-12-11      15.0  4.04  4.25  3.87  3.920000   3.920000  22310400.0  2020
# 2020-12-12      34.0  4.03  4.17  3.58  3.676667   3.676667         NaN  2020
# 2020-12-13      12.0  4.02  4.09  3.29  3.433333   3.433333         NaN  2020
# 2020-12-14      47.0  4.01  4.01  3.00  3.190000   3.190000  67159000.0  2020
# 2020-12-15      67.0  3.24  3.24  2.76  2.860000   2.860000  54432100.0  2020
# 2020-12-16      67.0  2.87  2.89  2.72  2.780000   2.780000  25423200.0  2020
# 2020-12-17      45.0  2.80  2.95  2.74  2.850000   2.850000  23799300.0  2020
#
#             Month  Day   datetime
# date
# 2020-12-08     12    8 2020-12-08
# 2020-12-09     12    9 2020-12-09
# 2020-12-10     12   10 2020-12-10
# 2020-12-11     12   11 2020-12-11
# 2020-12-12     12   12 2020-12-12
# 2020-12-13     12   13 2020-12-13
# 2020-12-14     12   14 2020-12-14
# 2020-12-15     12   15 2020-12-15
# 2020-12-16     12   16 2020-12-16
# 2020-12-17     12   17 2020-12-17

# %%
# #interpolated the NaN columns
# df_interpol = amc_result.groupby('date')\
#                 .resample('D')\
#                 .mean()
# df_interpol['Close'] = df_interpol['Close'].interpolate()
# df_interpol['Open'] = df_interpol['Open'].interpolate()
# df_interpol['High'] = df_interpol['High'].interpolate()
# df_interpol['Low'] = df_interpol['Low'].interpolate()
# df_interpol['Adj Close'] = df_interpol['Adj Close'].interpolate()
# # df_interpol['Volume'] = df_interpol['Volume'].interpolate()
# df_interpol.head(10)
# Out:
#                        mentions  Open  High   Low     Close  Adj Close  \
# date       date
# 2020-12-08 2020-12-08      11.0  3.61  4.02  3.61  3.980000   3.980000
# 2020-12-09 2020-12-09       2.0  4.22  4.33  3.75  3.860000   3.860000
# 2020-12-10 2020-12-10      26.0  3.79  4.10  3.77  4.090000   4.090000
# 2020-12-11 2020-12-11      15.0  4.04  4.25  3.87  3.920000   3.920000
# 2020-12-12 2020-12-12      34.0  4.03  4.17  3.58  3.676667   3.676667
# 2020-12-13 2020-12-13      12.0  4.02  4.09  3.29  3.433333   3.433333
# 2020-12-14 2020-12-14      47.0  4.01  4.01  3.00  3.190000   3.190000
# 2020-12-15 2020-12-15      67.0  3.24  3.24  2.76  2.860000   2.860000
# 2020-12-16 2020-12-16      67.0  2.87  2.89  2.72  2.780000   2.780000
# 2020-12-17 2020-12-17      45.0  2.80  2.95  2.74  2.850000   2.850000
#
#                            Volume  Year  Month  Day
# date       date
# 2020-12-08 2020-12-08  29530600.0  2020     12    8
# 2020-12-09 2020-12-09  20991200.0  2020     12    9
# 2020-12-10 2020-12-10  19872800.0  2020     12   10
# 2020-12-11 2020-12-11  22310400.0  2020     12   11
# 2020-12-12 2020-12-12         NaN  2020     12   12
# 2020-12-13 2020-12-13         NaN  2020     12   13
# 2020-12-14 2020-12-14  67159000.0  2020     12   14
# 2020-12-15 2020-12-15  54432100.0  2020     12   15
# 2020-12-16 2020-12-16  25423200.0  2020     12   16
# 2020-12-17 2020-12-17  23799300.0  2020     12   17

# %%
# df_interpol['datetime']=df_interpol.index.to_pydatetime()
# df_interpol["Year"]=df_interpol['datetime'].dt.year
# df_interpol["Month"]=df_interpol['datetime'].dt.month
# df_interpol["Day"]=df_interpol['datetime'].dt.day
# # df_interpol['date2']=df_interpol.index
# df_interpol.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-fb7fdf1df393> in <module>
# ----> 1 df_interpol['datetime']=df_interpol.index.to_pydatetime()
#       2 df_interpol["Year"]=df_interpol['datetime'].dt.year
#       3 df_interpol["Month"]=df_interpol['datetime'].dt.month
#       4 df_interpol["Day"]=df_interpol['datetime'].dt.day
#       5 # df_interpol['date2']=df_interpol.index
#
# AttributeError: 'MultiIndex' object has no attribute 'to_pydatetime'

# %%
# amc_result.interpolate(method ='linear', limit_direction ='forward')

# %%
plt.figure(figsize=(16,8))
plt.title('AMC Stocks Closing Price History Dec-Jan 2020-2021')
plt.plot(df_interpol['datetime'],df_interpol['Close'])
plt.xlabel('datetime',fontsize=18)
plt.ylabel('Close Price US($)',fontsize=18)
plt.style.use('fivethirtyeight')
plt.show()

# %%
#Plot Open vs Close
df_interpol[['Open','Close']].head(20).plot(kind='bar',figsize=(16,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
#Plot High vs Close
df_interpol[['High','Close']].head(20).plot(kind='bar',figsize=(16,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
#Plot Low vs Close
df_interpol[["Low", "Close"]].head(20).plot(kind="bar", figsize=(16,8))
plt.grid(which="major", linestyle="-", linewidth="0.5", color="green")
plt.grid(which="minor", linestyle=":", linewidth="0.5", color="black")
plt.show()

# %%
df_interpol["Year"]=df_interpol["datetime"].dt.year
df_interpol["Month"]=df_interpol["datetime"].dt.month
df_interpol["Day"]=df_interpol["datetime"].dt.day

# %%
df_interpol=df_interpol[["Day","Month","Year","High","Open","Low","Close"]]
df_interpol.head(10)
# Out:
#             Day  Month  Year  High  Open   Low     Close
# date
# 2020-12-08    8     12  2020  4.02  3.61  3.61  3.980000
# 2020-12-09    9     12  2020  4.33  4.22  3.75  3.860000
# 2020-12-10   10     12  2020  4.10  3.79  3.77  4.090000
# 2020-12-11   11     12  2020  4.25  4.04  3.87  3.920000
# 2020-12-12   12     12  2020  4.17  4.03  3.58  3.676667
# 2020-12-13   13     12  2020  4.09  4.02  3.29  3.433333
# 2020-12-14   14     12  2020  4.01  4.01  3.00  3.190000
# 2020-12-15   15     12  2020  3.24  3.24  2.76  2.860000
# 2020-12-16   16     12  2020  2.89  2.87  2.72  2.780000
# 2020-12-17   17     12  2020  2.95  2.80  2.74  2.850000

# %%
#separate Independent and dependent variable
X = df_interpol.iloc[:,df_interpol.columns !="Close"]
Y = df_interpol.iloc[:, 5]

# %%
print(X.shape) 
print(Y.shape)
# Out:
# (59, 6)
# (59,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(X,Y,test_size=.25)

# %%
print(x_train.shape) 
print(x_test.shape) 
print(y_train.shape) 
print(y_test.shape)
# Out:
# (44, 6)
# (15, 6)
# (44,)
# (15,)

# %%
lr_model=LinearRegression()
lr_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# y_pred=lr_model.predict(x_test)
y_pred = lr_model.predict(x_test)
print(y_pred.shape)
# Out:
# (15,)

# %%
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-b9a5771aa983> in <module>
# ----> 1 plt.scatter(X, Y)
#       2 plt.plot(X, Y_pred, color='red')
#       3 plt.show()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4389         y = np.ma.ravel(y)
#    4390         if x.size != y.size:
# -> 4391             raise ValueError("x and y must be the same size")
#    4392
#    4393         if s is None:
#
# ValueError: x and y must be the same size

# %%
#Linear Model Cross-Validation
from sklearn import model_selection
from sklearn.model_selection import KFold
kfold = model_selection.KFold(n_splits=15, random_state=15)
results_kfold = model_selection.cross_val_score(lr_model, x_test, y_test.astype('int'), cv=kfold)
print("Accuracy: ", results_kfold.mean()*100)
# Out:
# Accuracy:  nan
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/model_selection/_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/_regression.py:589: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/_regression.py:589: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/_regression.py:589: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/_regression.py:589: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/_regression.py:589: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/_regression.py:589: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/_regression.py:589: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/_regression.py:589: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/_regression.py:589: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/_regression.py:589: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/_regression.py:589: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/_regression.py:589: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/_regression.py:589: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/_regression.py:589: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/chelseaconrad/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/_regression.py:589: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
#Plot actual vs predicted
plot_df=pd.DataFrame({‘Actual’:y_test,’Pred’:y_pred})
plot_df.head(20).plot(kind='bar',figsize=(16,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
#   File "<ipython-input-88-b7c9d2668317>", line 2
#     plot_df=pd.DataFrame({‘Actual’:y_test,’Pred’:y_pred})
#                                  ^
# SyntaxError: invalid character in identifier
