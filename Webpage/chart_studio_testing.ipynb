# %%
import pandas as pd
import numpy as np
import scipy as sp
import chart_studio.plotly as py
import plotly.figure_factory as ff
chart_studio.tools.set_credentials_file(username='Gfinin3', )

# %%
import chart_studio

# %%
df = pd.read_csv('/Users/gregfinin/Downloads/comments_df_agg_plotly.csv')

# %%
df
# Out:
#       gme    amc     bb    date
# 0    2924     22    424  14-Dec
# 1    2682     12    913  15-Dec
# 2     946     34    997  16-Dec
# 3     599     38    733  17-Dec
# 4     348     46    677  18-Dec
# 5     470     20    413  19-Dec
# 6    1025     79    539  20-Dec
# 7    1123    109    536  21-Dec
# 8     587    110    495  22-Dec
# 9     763    107    960  23-Dec
# 10   1165     37    955  24-Dec
# 11    365     17    452  25-Dec
# 12    369     12    379  26-Dec
# 13   1071    108    588  27-Dec
# 14   3690     57    729  28-Dec
# 15   4494     41    733  29-Dec
# 16   2040     10    454  30-Dec
# 17    966     25    331  31-Dec
# 18   1050     29    312   1-Jan
# 19   1317     32    428   2-Jan
# 20   2935     73    549   3-Jan
# 21   2551     54    664   4-Jan
# 22   2056     56    537   5-Jan
# 23   3097     52    566   6-Jan
# 24   1012     21    337   7-Jan
# 25   1098      8    404   8-Jan
# 26    719      3    341   9-Jan
# 27   1782     10    537  10-Jan
# ...

# %%
import plotly.graph_objects as go
from plotly.offline import plot

# %%
chart_studio.tools.set_credentials_file(username='Gfinin3', api_key='bKGMtXssJ8qljnjy6Ao5')

# %%
data = [go.Bar(x=df.date,
            y=df.gme)]

py.iplot(data, filename='jupyter-basic_bar')
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~Gfinin3/3.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
