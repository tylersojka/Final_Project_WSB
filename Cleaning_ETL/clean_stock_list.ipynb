# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ticker_list = pd.read_csv("../stocks_df_final.csv")

# %%
ticker_list
# Out:
#      Ticker Name  Ticker Count
# 0             AA            20
# 1           AACG             0
# 2           AACQ             0
# 3          AACQU             0
# 4          AACQW             0
# ...          ...           ...
# 6930       ZWRKW             0
# 6931        ZYME             1
# 6932        ZYNE             2
# 6933        ZYXI             1
# 6934         SLV           862
#
# [6935 rows x 2 columns]

# %%
ticker_list.sort_values(by="Ticker Count", ascending=False)
# Out:
#      Ticker Name  Ticker Count
# 2732         GME         52231
# 326          AMC         22200
# 4328        NEXT         11282
# 707           BB          7235
# 2782        GOOD          6508
# ...          ...           ...
# 2845       GSAQU             0
# 2844     GSAH.WS             0
# 2843      GSAH.U             0
# 2842        GSAH             0
# 3467         JQC             0
#
# [6935 rows x 2 columns]

# %%
ticker_list.plot(x="Ticker Name", y="Ticker Count")
plt.show()

# %%
ticker_list = ticker_list[ticker_list["Ticker Count"] != 0]

# %%
ticker_list = ticker_list.sort_values(by="Ticker Count", ascending=False)

# %%
ticker_list.head(60)
# Out:
#      Ticker Name  Ticker Count
# 2732         GME         52231
# 326          AMC         22200
# 4328        NEXT         11282
# 707           BB          7235
# 2782        GOOD          6508
# 4437         NOK          6441
# 2064        ELSE          3282
# 5026        POST          3279
# 788         BEST          3065
# 2552        FUND          2971
# 5285        REAL          2871
# 2943          HE          2632
# 2476        FREE          2576
# 4968        PLAY          2266
# 6518        VERY          2206
# 6114        TELL          2187
# 1125        CASH          1997
# 5907        STAY          1987
# 3714        LIFE          1859
# 6751        WORK          1608
# 3725        LIVE          1411
# 4982        PLTR          1407
# 6366           U          1345
# 5453         RUN          1321
# 6084          TD          1241
# 4245        NAKD          1161
# 4967        PLAN          1126
# 5510        SAVE          1119
# 431         APPS          1097
# ...

# %%
black_list = ["NEXT", "GOOD". "ELSE", "POST", "BEST", "FUND", "REAL"]
