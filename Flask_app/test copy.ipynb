# %%
import os
import pandas as pd
from flask import Flask, render_template, redirect
from flask_sqlalchemy import SQLAlchemy
from sqlalchemy import create_engine


engine = create_engine(os.getenv("postgres_uri"))

# %%
import plotly.graph_objects as go
import plotly

# %%
query = '''select * from mentions_and_price'''
price_mentions_data = pd.read_sql(query, engine)

price_mentions_data
# Out:
#             date Unnamed: 1   Adj Close       Close        High         Low  \
# 0     2020-12-08        AAL   17.629999   17.629999   17.920000   17.160000
# 1     2020-12-08       AAPL  124.194412  124.379997  124.980003  123.089996
# 2     2020-12-08       ALOT   11.680000   11.680000   11.740000   11.500000
# 3     2020-12-08        AMC    3.980000    3.980000    4.020000    3.610000
# 4     2020-12-08       AMCX   31.070000   31.070000   32.139999   30.889999
# ...          ...        ...         ...         ...         ...         ...
# 4833  2021-02-04       TRHC   53.450001   53.450001   54.490002   52.770000
# 4834  2021-02-04       TRIT    6.920000    6.920000    7.160000    6.900000
# 4835  2021-02-04       TSLA  849.989990  849.989990  856.500000  833.419983
# 4836  2021-02-04       VXRT    9.050000    9.050000   10.500000    8.910000
# 4837  2021-02-04       ZYXI   18.160000   18.160000   18.980000   17.910000
#
#             Open      Volume  mentions
# 0      17.469999  95855400.0      21.0
# 1     124.370003  82225500.0      88.0
# 2      11.520000     27100.0       4.0
# 3       3.610000  29530600.0      11.0
# 4      31.280001    591300.0       0.0
# ...          ...         ...       ...
# 4833   54.290001    331900.0       0.0
# 4834    7.150000   4005300.0       0.0
# 4835  855.000000  15812700.0       0.0
# 4836    9.940000  37896600.0       0.0
# 4837   18.910000    559300.0       0.0
#
# [4838 rows x 9 columns]

# %%
price_mentions_data.rename(columns={'Unnamed: 1':"Ticker"}, inplace=True)

# %%
new_df = price_mentions_data.set_index('Ticker').sort_index()

# %%
new_df
# Out:
#               date  Adj Close      Close       High        Low       Open  \
# Ticker
# AAL     2020-12-08  17.629999  17.629999  17.920000  17.160000  17.469999
# AAL     2021-01-24        NaN        NaN        NaN        NaN        NaN
# AAL     2020-12-20        NaN        NaN        NaN        NaN        NaN
# AAL     2020-12-28  16.059999  16.059999  16.459999  15.910000  15.970000
# AAL     2021-01-16        NaN        NaN        NaN        NaN        NaN
# ...            ...        ...        ...        ...        ...        ...
# ZYXI    2021-01-22  17.540001  17.540001  17.670000  16.000000  16.049999
# ZYXI    2020-12-19        NaN        NaN        NaN        NaN        NaN
# ZYXI    2021-01-23        NaN        NaN        NaN        NaN        NaN
# ZYXI    2021-01-20  17.820000  17.820000  18.500000  17.360001  18.400000
# ZYXI    2021-02-04  18.160000  18.160000  18.980000  17.910000  18.910000
#
#             Volume  mentions
# Ticker
# AAL     95855400.0      21.0
# AAL            NaN       1.0
# AAL            NaN      16.0
# AAL     61099000.0      17.0
# AAL            NaN       4.0
# ...            ...       ...
# ZYXI      553100.0       0.0
# ZYXI           NaN       0.0
# ZYXI           NaN       0.0
# ZYXI      704800.0       0.0
# ZYXI      559300.0       0.0
#
# [4838 rows x 8 columns]

# %%
new_df['Volume'] = new_df['Volume'].fillna(value=0)

# %%
new_df = new_df.fillna(method='ffill')

# %%
df = new_df

# %%
trace1 = {
    'x': df.index,
    'open': df.Open,
    'close': df.Close,
    'high': df.High,
    'low': df.Low,
    'type': 'candlestick',
    'name': 'MSFT',
    'showlegend': True
}

# %%
data = [trace1]
# Config graph layout
layout = go.Layout({
    'title': {
        'text': 'Microsoft(MSFT) Moving Averages',
        'font': {
            'size': 15
        }
    }
})

# %%
fig = go.Figure(data, layout)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-30cdb2ea906d> in <module>
#       1 fig = go.Figure(data, layout)
# ----> 2 fig.show()
#
# /opt/anaconda3/envs/final/lib/python3.9/site-packages/plotly/basedatatypes.py in show(self, *args, **kwargs)
#    3395         import plotly.io as pio
#    3396
# -> 3397         return pio.show(self, *args, **kwargs)
#    3398
#    3399     def to_json(self, *args, **kwargs):
#
# /opt/anaconda3/envs/final/lib/python3.9/site-packages/plotly/io/_renderers.py in show(fig, renderer, validate, **kwargs)
#     395
#     396         if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> 397             raise ValueError(
#     398                 "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     399             )
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
import pandas as pd
from pandas_datareader import data as web
import plotly.graph_objects as go

# %%
stock = 'MSFT'
 
df = web.DataReader(stock, data_source='yahoo', start='01-01-2019')

# %%
df
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2019-01-02  101.750000   98.940002   99.550003  101.120003  35329300.0
# 2019-01-03  100.190002   97.199997  100.099998   97.400002  42579100.0
# 2019-01-04  102.510002   98.930000   99.720001  101.930000  44060600.0
# 2019-01-07  103.269997  100.980003  101.639999  102.059998  35656100.0
# 2019-01-08  103.970001  101.709999  103.040001  102.800003  31514400.0
# ...                ...         ...         ...         ...         ...
# 2021-03-01  237.470001  233.149994  235.899994  236.940002  25324000.0
# 2021-03-02  237.300003  233.449997  237.009995  233.869995  22785500.0
# 2021-03-03  233.580002  227.259995  232.160004  227.559998  33950400.0
# 2021-03-04  232.490005  224.259995  226.740005  226.729996  44584200.0
# 2021-03-05  233.270004  226.460007  229.520004  231.600006  41842100.0
#
#              Adj Close
# Date
# 2019-01-02   98.375481
# 2019-01-03   94.756454
# 2019-01-04   99.163513
# 2019-01-07   99.289970
# 2019-01-08  100.009888
# ...                ...
# 2021-03-01  236.940002
# 2021-03-02  233.869995
# 2021-03-03  227.559998
# 2021-03-04  226.729996
# 2021-03-05  231.600006
#
# [548 rows x 6 columns]

# %%
trace1 = {
    'x': df.index,
    'open': df.Open,
    'close': df.Close,
    'high': df.High,
    'low': df.Low,
    'type': 'candlestick',
    'name': 'MSFT',
    'showlegend': True
}

# %%
data = [trace1]
# Config graph layout
layout = go.Layout({
    'title': {
        'text': 'Microsoft(MSFT) Moving Averages',
        'font': {
            'size': 15
        }
    }
})

# %%
fig = go.Figure(data, layout)
fig.show()
